# %% [markdown]
# # Covid Project - 4

# %%
import pandas as pd

# %%
covid=pd.read_csv('dataset/covid.csv')

# %%
covid
# Out:
#                                       States  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10502      40       10333
# 1                             Andhra Pradesh      2333710    1453     2317524
# 2                          Arunachal Pradesh        66246     295       65655
# 3                                      Assam       741541    4006      729513
# 4                                      Bihar       844997    1024      831688
# 5                                 Chandigarh        97442     772       95499
# 6                               Chhattisgarh      1169532    3282     1152169
# 7   Dadra and Nagar Haveli and Daman and Diu        11557      23       11530
# 8                                      Delhi      1970899    7484     1937079
# 9                                        Goa       253162    1046      248261
# 10                                   Gujarat      1261922    5862     1245080
# ...

# %%
#1.How many no. of records & columns?
covid.shape
# Out:
# (36, 9)

# %%
#2.Display all columns name?
covid.columns
# Out:
# Index(['States', 'Total Cases', 'Active', 'Discharged', 'Deaths', 'Active.1',
#        'Discharge ', 'Death ', 'Population'],
#       dtype='object')

# %%
covid.columns.tolist()
# Out:
# ['States',
#  'Total Cases',
#  'Active',
#  'Discharged',
#  'Deaths',
#  'Active.1',
#  'Discharge ',
#  'Death ',
#  'Population']

# %%
#3.Show all unique states name?
covid.States.unique()
# Out:
# array(['Andaman and Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telengana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
#4.Show only starting five records?
covid.head()
# Out:
#                 States  Total Cases  Active  Discharged  Deaths  Active.1  \
# 0  Andaman and Nicobar        10502      40       10333     129      0.38
# 1       Andhra Pradesh      2333710    1453     2317524   14733      0.06
# 2    Arunachal Pradesh        66246     295       65655     296      0.45
# 3                Assam       741541    4006      729513    8022      0.54
# 4                Bihar       844997    1024      831688   12285      0.12
#
#    Discharge   Death   Population
# 0       98.39    1.23   100896618
# 1       99.31    0.63   128500364
# 2       99.11    0.45      658019
# 3       98.38    1.08      290492
# 4       98.42    1.45    40100376

# %%
#5.Show only last five records?
covid.tail()
# Out:
#            States  Total Cases  Active  Discharged  Deaths  Active.1  \
# 31      Telengana       826284    5667      816506    4111      0.69
# 32        Tripura       107419     653      105831     935      0.61
# 33  Uttar Pradesh      2108686    5440     2079670   23576      0.26
# 34    Uttarakhand       445106    2378      435009    7719      0.53
# 35    West Bengal      2099433    7302     2070731   21400      0.35
#
#     Discharge   Death   Population
# 31       98.82    0.50    69599762
# 32       98.52    0.87     1646050
# 33       98.62    1.12     1158040
# 34       97.73    1.73    85002417
# 35       98.63    1.02    32199722

# %%
#6.Show any random record?
covid.sample()
# Out:
#        States  Total Cases  Active  Discharged  Deaths  Active.1  Discharge   \
# 5  Chandigarh        97442     772       95499    1171      0.79       98.01
#
#    Death   Population
# 5     1.2    30501026

# %%
covid.dtypes
# Out:
# States          object
# Total Cases      int64
# Active           int64
# Discharged       int64
# Deaths           int64
# Active.1       float64
# Discharge      float64
# Death          float64
# Population       int64
# dtype: object

# %%
#7.Show the number of confirmed, deaths and recovered cases in each states.
covid.groupby('States').sum()
# Out:
#                                           Total Cases  Active  Discharged  \
# States
# Andaman and Nicobar                             10502      40       10333
# Andhra Pradesh                                2333710    1453     2317524
# Arunachal Pradesh                               66246     295       65655
# Assam                                          741541    4006      729513
# Bihar                                          844997    1024      831688
# Chandigarh                                      97442     772       95499
# Chhattisgarh                                  1169532    3282     1152169
# Dadra and Nagar Haveli and Daman and Diu        11557      23       11530
# Delhi                                         1970899    7484     1937079
# Goa                                            253162    1046      248261
# Gujarat                                       1261922    5862     1245080
# Haryana                                       1036795    4598     1021547
# ...

# %%
covid.groupby('Deaths').sum().head(10)
# Out:
#         Total Cases  Active  Discharged  Active.1  Discharge   Death   \
# Deaths
# 4             11557      23       11530      0.20       99.77    0.03
# 52            11415       0       11363      0.00       99.54    0.46
# 129           10502      40       10333      0.38       98.39    1.23
# 228           29021     118       28675      0.41       98.81    0.79
# 296           66246     295       65655      0.45       99.11    0.45
# 474           42784     476       41834      1.11       97.78    1.11
# 712          234387    1214      232461      0.52       99.18    0.30
# 772           35838      54       35012      0.15       97.70    2.15
# 935          107419     653      105831      0.61       98.52    0.87
# 1171          97442     772       95499      0.79       98.01    1.20
#
#         Population
# Deaths
# 4        231502578
# 52        11700099
# 129      100896618
# 228        4184959
# 296         658019
# 474       83697770
# 712        1308967
# ...

# %%
covid.groupby('States')['Active'].sum()
# Out:
# States
# Andaman and Nicobar                            40
# Andhra Pradesh                               1453
# Arunachal Pradesh                             295
# Assam                                        4006
# Bihar                                        1024
# Chandigarh                                    772
# Chhattisgarh                                 3282
# Dadra and Nagar Haveli and Daman and Diu       23
# Delhi                                        7484
# Goa                                          1046
# Gujarat                                      5862
# Haryana                                      4598
# Himachal Pradesh                             4919
# Jammu and Kashmir                            5045
# Jharkhand                                     837
# Karnataka                                   11252
# Kerala                                      10179
# Ladakh                                        118
# Lakshadweep                                     0
# ...

# %%
covid.groupby('States')['Active','Deaths','Discharged'].sum()
# Out:
# C:\Users\Deepak\AppData\Local\Temp\ipykernel_7328\2534232990.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   covid.groupby('States')['Active','Deaths','Discharged'].sum()
#                                           Active  Deaths  Discharged
# States
# Andaman and Nicobar                           40     129       10333
# Andhra Pradesh                              1453   14733     2317524
# Arunachal Pradesh                            295     296       65655
# Assam                                       4006    8022      729513
# Bihar                                       1024   12285      831688
# Chandigarh                                   772    1171       95499
# Chhattisgarh                                3282   14081     1152169
# Dadra and Nagar Haveli and Daman and Diu      23       4       11530
# Delhi                                       7484   26336     1937079
# ...

# %%
#8.In which state maximum number of active cases were recorded?
covid.groupby('States')['Active'].sum().sort_values(ascending=False)
# Out:
# States
# Punjab                                      12429
# Maharashtra                                 11968
# Karnataka                                   11252
# Kerala                                      10179
# Tamil Nadu                                   9408
# Delhi                                        7484
# West Bengal                                  7302
# Gujarat                                      5862
# Odisha                                       5851
# Telengana                                    5667
# Uttar Pradesh                                5440
# Jammu and Kashmir                            5045
# Himachal Pradesh                             4919
# Haryana                                      4598
# Assam                                        4006
# Rajasthan                                    3813
# Chhattisgarh                                 3282
# Uttarakhand                                  2378
# Andhra Pradesh                               1453
# ...

# %%
covid.groupby('States')['Active'].sum().sort_values(ascending=True)
# Out:
# States
# Lakshadweep                                     0
# Dadra and Nagar Haveli and Daman and Diu       23
# Andaman and Nicobar                            40
# Nagaland                                       54
# Ladakh                                        118
# Manipur                                       244
# Arunachal Pradesh                             295
# Sikkim                                        476
# Puducherry                                    640
# Tripura                                       653
# Meghalaya                                     686
# Chandigarh                                    772
# Jharkhand                                     837
# Bihar                                        1024
# Goa                                          1046
# Mizoram                                      1214
# Madhya Pradesh                               1349
# Andhra Pradesh                               1453
# Uttarakhand                                  2378
# ...

# %%
#9.In which state minimum number of deaths were recorded?
covid.groupby('States').Deaths.sum().sort_values(ascending=True).head(15)
# Out:
# States
# Dadra and Nagar Haveli and Daman and Diu       4
# Lakshadweep                                   52
# Andaman and Nicobar                          129
# Ladakh                                       228
# Arunachal Pradesh                            296
# Sikkim                                       474
# Mizoram                                      712
# Nagaland                                     772
# Tripura                                      935
# Chandigarh                                  1171
# Meghalaya                                   1611
# Puducherry                                  1967
# Manipur                                     2138
# Goa                                         3855
# Telengana                                   4111
# Name: Deaths, dtype: int64

# %%
#10.How many confirmed, Death, Active, Discharged cases were reported for Delhi?
covid[covid.States=='Delhi']
# Out:
#   States  Total Cases  Active  Discharged  Deaths  Active.1  Discharge   \
# 8  Delhi      1970899    7484     1937079   26336      0.38       98.28
#
#    Death   Population
# 8    1.34      773997

# %%
covid.describe()
# Out:
#         Total Cases        Active    Discharged         Deaths   Active.1  \
# count  3.600000e+01     36.000000  3.600000e+01      36.000000  36.000000
# mean   1.227074e+06   3661.305556  1.208780e+06   14632.555556   0.460556
# std    1.813338e+06   3786.588859  1.784934e+06   27063.901871   0.377941
# min    1.050200e+04      0.000000  1.033300e+04       4.000000   0.000000
# 25%    1.049248e+05    649.750000  1.032480e+05    1112.000000   0.197500
# 50%    6.058710e+05   1915.500000  5.949465e+05    6523.500000   0.380000
# 75%    1.303242e+06   5713.000000  1.289440e+06   14244.000000   0.532500
# max    8.060737e+06  12429.000000  7.900626e+06  148143.000000   1.610000
#
#        Discharge      Death     Population
# count   36.000000  36.000000  3.600000e+01
# mean    98.435556   1.103889  3.971861e+07
# std      0.687436   0.484050  5.050913e+07
# min     96.110000   0.030000  6.600100e+04
# 25%     98.047500   0.850000  1.695473e+06
# ...

# %%
import matplotlib.pyplot as plt

# %%
covid.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
covid['Discharged'].max()
# Out:
# 7900626

# %%
covid['Active'].max()
# Out:
# 12429

# %%
covid['Population'].max()
# Out:
# 231502578

# %%
covid['Population'].min()
# Out:
# 66001

# %%
covid['Total Cases'].max()
# Out:
# 8060737

# %%
covid['Total Cases'].min()
# Out:
# 10502
